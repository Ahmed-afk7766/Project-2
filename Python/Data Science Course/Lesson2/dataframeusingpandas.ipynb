# %%
import pandas as pd
import numpy as np

# %%
exam_data = {'name' :['Anantasia', 'Dime', 'kath', 'jamees', 'Emily', ' Micheal', 'Mathew',
'laura', 'Kevin', 'Jonas'],
       'score':[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
       'attempts':[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
       'qualify':['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(exam_data, index=labels)
print("Summary of the basic information about this Dataframeand its data:")
print(df.info())
# Out:
# Summary of the basic information about this Dataframeand its data:
# <class 'pandas.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     str
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 400.0+ bytes
# None
